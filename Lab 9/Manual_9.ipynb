# %% [markdown]
# ---
# # **Task 1**

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense
from sklearn import datasets
import pandas as pd

data = tf.keras.datasets.mnist.load_data()

(xTrain, yTrain), (xTest, yTest) = data
blackNWhite = 255

xTrain = xTrain.astype('int32') / blackNWhite
xTest = xTest.astype('int32') / blackNWhite

fig, ax = plt.subplots(10, 10)
k = 0

for i in range(10):
  for j in range(10):
    ax[i][j].imshow(xTrain[k].reshape(28, 28), aspect = 'auto')
    ax[i][j].axis('off')
    k += 1
plt.show()

model = Sequential([
    Flatten(input_shape = (28, 28)),
    Dense(128, activation = 'relu'),
    Dense(10, activation = 'softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(xTrain, yTrain, epochs=25, validation_split=0.2)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8633 - loss: 0.4824 - val_accuracy: 0.9564 - val_loss: 0.1534
# Epoch 2/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9632 - loss: 0.1308 - val_accuracy: 0.9645 - val_loss: 0.1236
# Epoch 3/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9753 - loss: 0.0837 - val_accuracy: 0.9714 - val_loss: 0.0967
# Epoch 4/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9824 - loss: 0.0599 - val_accuracy: 0.9672 - val_loss: 0.1071
# Epoch 5/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.9869 - loss: 0.0469 - val_accuracy: 0.9737 - val_loss: 0.0913
# Epoch 6/25
# ...

# %%
results = model.evaluate(xTest, yTest, verbose = 0)
print(f'Loss: {results[0]}')
print(f'Accuracy: {results[1]}')
# Out:
# Loss: 0.11415716260671616
# Accuracy: 0.9789000153541565

# %%
plt.figure(figsize=(12, 5))

# Plotting Training and Validation Accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy', color='blue')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', color='orange')
plt.title('Training and Validation Accuracy', fontsize=14)
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Accuracy', fontsize=12)
plt.legend()
plt.grid(True)

# Plotting Training and Validation Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')
plt.title('Training and Validation Loss', fontsize=14)
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Loss', fontsize=12)
plt.legend()
plt.grid(True)

plt.suptitle("Model Training Performance", fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# # **Part 2**

# %% [markdown]
# ---
# ##### **Task 1**

# %%
data = datasets.load_iris()
df = pd.DataFrame(data.data, columns = data.feature_names)
df.head() # First 5 Rows
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %% [markdown]
# ---
# ##### **Task 2**

# %%
import matplotlib.pyplot as plt
from sklearn import datasets

data = datasets.load_iris()
x = data.data[:, 0]
y = data.data[:, 1]
labels = data.target
label_names = data.target_names

colors = ['red', 'green', 'blue']

for i, label_name in enumerate(label_names):
    plt.scatter(x[labels == i], y[labels == i],
                color=colors[i], label=label_name)

plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.title('Sepal Length vs Sepal Width by Species')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ---
# ##### **Task 3**

# %%
d1 = df['sepal length (cm)']
d2 = df['sepal width (cm)']
d3 = df['petal length (cm)']
d4 = df['petal width (cm)']

plt.subplot(2, 2, 1)
plt.hist(d1, color = 'crimson', edgecolor = 'black')
plt.title('Sepal Length')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Frequency')

plt.subplot(2, 2, 2)
plt.hist(d1, color = 'mediumseagreen', edgecolor = 'black')
plt.title('Sepal Width')
plt.xlabel('Sepal Width (cm)')
plt.ylabel('Frequency')

plt.subplot(2, 2, 3)
plt.hist(d1, color = 'royalblue', edgecolor = 'black')
plt.title('Petal Length')
plt.xlabel('Petal Length (cm)')
plt.ylabel('Frequency')

plt.subplot(2, 2, 4)
plt.hist(d1, color = 'darkorange', edgecolor = 'black')
plt.title('Petal Width')
plt.xlabel('Petal Width (cm)')
plt.ylabel('Frequency')

plt.tight_layout()

plt.show()

# %%
data = datasets.load_iris()
df = pd.DataFrame(data.data, columns=data.feature_names)

df['species'] = data.target

df['species'] = df['species'].map({0: 'Setosa', 1: 'Versicolor', 2: 'Virginica'})

x1, x2, x3 = [], [], []

for i, species in enumerate(df['species']):
  if species == 'Setosa':
    x1.append(df['petal width (cm)'][i])
  if species == 'Versicolor':
    x2.append(df['petal width (cm)'][i])
  if species == 'Virginica':
    x3.append(df['petal width (cm)'][i])

Data = [x1, x2, x3]

plt.boxplot(Data, tick_labels = ['Setosa', 'Versicolor', 'Virginica'], vert = False)
plt.title('Petal Width by Species', fontsize = 12)
plt.xlabel('Petal Width (cm)', fontsize = 12)
plt.ylabel('Species', fontsize = 12)
plt.grid(True)
plt.show()
